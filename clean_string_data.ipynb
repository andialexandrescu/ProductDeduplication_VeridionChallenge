# %% [markdown]
# # <div style = 'background-color:skyblue'> <center> Data cleaning (Step 1) </div>
#
# ---
# ### Project Overview
# This project is divided into <b>three parts</b>, each focused on a main task and implemented in <b>separate</b> Jupyter Notebooks. Jupyter variables can be easily toggled in the menu above. To facilitate communication between these notebooks, values will be stored using `%store` and retrieved as required using `%store -r`. The approach I used to tackle this challenge involved these sub-tasks in order:
#
# ### Sections
# 1. Data cleaning (looking for accuracy and consistency) -  [`clean_string_data.ipynb` (link for path here)](./clean_string_data.ipynb)
# 2. Filtering similarities using different algorithms on significant columns to identify potential entries - [ `filter_data_similarity.ipynb` (link for path here)](./filter_data_similarity.ipynb)
# 3. Merging the similar pairs retrieved at the previous step by creating groups and consolidating them into single enriched entities - [`group_duplicates_consolidate_groups.ipynb` (link for path here)](./group_duplicates_consolidate_groups.ipynb)
# ---

# %% [markdown]
# ### Table of Contents
#
# - [Analysing the dataset](#analysing-the-dataset)
# - [Normalization (lowercasing + removing any characters that are not alphanumeric)](#normalization)
# - [Tokenization (and normalization: removing stop words)](#tokenization)

# %% [markdown]
# ### Analysing the dataset
# In order to open the given dataset, which has a `.parquet` extension, I imported `pandas`, as it is well-suited for handling even this file format and will come to use later in the project for transforming matrices into data frames when analysing the concept of sparsity.

# %%
import pandas as pd

df = pd.read_parquet('data\\veridion_product_deduplication_challenge.snappy.parquet')
df
# Out:
#                                                   unspsc  \
# 0      Sewing and stitchery and weaving equipment and...
# 1                 Electric alternating current AC motors
# 2                     Vehicle trim and exterior covering
# 3                                        Pipe connectors
# 4                                                  Doors
# ...                                                  ...
# 21941                                              Other
# 21942                     Processed and synthetic rubber
# 21943                            Fresh cut rose bouquets
# 21944  Vision correction or cosmetic eyewear and rela...
# 21945       Chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-CST-HGD-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                        product_title  \
# 0                        Glimakra Warping Board (8m)
# 1                            NMRV Worm Gearbox Motor
# 2                           Nissan R33 GTR Car Cover
# 3                                  Flexible Fittings
# 4                   CST-HGD-33103 Hinged Closet Door
# ...                                              ...
# 21941                              15/16 Accessories
# 21942                General Mechanical Rubber Goods
# 21943                          Luxurious Rose Garden
# 21944  Dailies AquaComfort Plus Multifocal (30 Pack)
# 21945   Signature Dark Collection 85% Dark Chocolate
#
#                                          product_summary  \
# 0      The Glimakra Warping Board is designed for use...
# 1      The NMRV Worm Gearbox Motor is a high-efficien...
# 2      A custom car cover designed for the Nissan R33...
# 3      Flexible fittings for plumbing applications, a...
# 4      The CST-HGD-33103 Hinged Closet Door is a meti...
# ...                                                  ...
# 21941  Accessories designed for Sweet 15/16, availabl...
# 21942  A category of rubber goods designed for genera...
# 21943  The Luxurious Rose Garden is a stunning floral...
# 21944  A pack of 30 Dailies AquaComfort Plus Multifoc...
# 21945  A Signature Dark Collection product from Malag...
#
#                     product_name product_identifier  \
# 0                  Warping Board                 []
# 1             Worm Gearbox Motor                 []
# 2                      Car Cover                 []
# 3              Flexible Fittings                 []
# 4             Hinged Closet Door                 []
# ...                          ...                ...
# 21941                Accessories                 []
# 21942               Rubber Goods                 []
# 21943         Floral Arrangement                 []
# 21944  Multifocal Contact Lenses                 []
# 21945             Dark Chocolate                 []
#
#                             brand              intended_industries  \
# 0                            None                        [Textile]
# 1                            None                     [Industrial]
# 2                            None                     [Automotive]
# 3                            None                       [Plumbing]
# 4                             CST  [Home Appliances, Construction]
# ...                           ...                              ...
# 21941                        None                         [Retail]
# 21942                        None                  [Manufacturing]
# 21943  Lily Of The Valley Florist                  [Retail, Gifts]
# 21944                     Dailies                     [Healthcare]
# 21945           Malagos Chocolate                [Food & Beverage]
#
#                                  applicability  ...     form  \
# 0                       [use with floor looms]  ...       []
# 1                    [industrial applications]  ...       []
# 2      [protecting vehicles from the elements]  ...       []
# 3                     [plumbing installations]  ...       []
# 4                             [Closet Storage]  ...       []
# ...                                        ...  ...      ...
# 21941            [accessories for Sweet 15/16]  ...       []
# 21942                                       []  ...       []
# 21943           [gifting, decorative purposes]  ...       []
# 21944                      [vision correction]  ...       []
# 21945                                       []  ...  [Solid]
#
#                                                     size  \
# 0      [{'dimension': 'Length', 'qualitative': False,...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 21941  [{'dimension': 'Diameter', 'qualitative': Fals...
# 21942                                                 []
# 21943  [{'dimension': 'Width', 'qualitative': False, ...
# 21944                                                 []
# 21945                                                 []
#
#                                                    color purity  \
# 0                                                     []     []
# 1      [{'original': 'Blue', 'simple': 'Blue'}, {'ori...     []
# 2                                                     []     []
# 3                                                     []     []
# 4                                                     []     []
# ...                                                  ...    ...
# 21941                                                 []     []
# 21942                                                 []     []
# 21943                                                 []     []
# 21944                                                 []     []
# 21945                                                 []     []
#
#       energy_efficiency pressure_rating  \
# 0                  None              []
# 1                  None              []
# 2                  None              []
# 3                  None              []
# 4                  None              []
# ...                 ...             ...
# 21941              None              []
# 21942              None              []
# 21943              None              []
# 21944              None              []
# 21945              None              []
#
#                                             power_rating  \
# 0                                                     []
# 1      [{'qualitative': False, 'type': 'min', 'unit':...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 21941                                                 []
# 21942                                                 []
# 21943                                                 []
# 21944                                                 []
# 21945                                                 []
#
#        quality_standards_and_certifications  \
# 0                                        []
# 1                                        []
# 2                                        []
# 3                                        []
# 4                                        []
# ...                                     ...
# 21941                                    []
# 21942                                    []
# 21943                                    []
# 21944                                    []
# 21945                                    []
#
#                                   miscellaneous_features  \
# 0                                                     []
# 1      [Omnibearing installation, High radiation effi...
# 2      [Personalization with custom brand logos, grap...
# 3      [allows for movement, flexibility in installat...
# 4      [Italian craftsmanship, German engineering, Sm...
# ...                                                  ...
# 21941                      [part of the sale collection]
# 21942                                                 []
# 21943  [Product images available in various resolutions]
# 21944                                                 []
# 21945                                                 []
#
#                                              description
# 0      The "Warping Board" is designed for use with f...
# 1      The "Worm Gearbox Motor" is a high-efficiency ...
# 2      The "Car Cover" is a custom-designed cover tai...
# 3      "Flexible Fittings" are designed for plumbing ...
# 4      The "Hinged Closet Door" is a storage solution...
# ...                                                  ...
# 21941  "Accessories" are designed for use with Sweet ...
# 21942  "Rubber Goods" are designed for general mechan...
# 21943  "The 'Floral Arrangement' offered by Lily Of T...
# 21944  "Multifocal Contact Lenses" are designed for d...
# 21945  "Dark Chocolate" from Malagos Chocolate is a r...
#
# [21946 rows x 31 columns]

# %% [markdown]
# We can note that there are **21946** product entries, containing diverse columns such as:
# - `unspsc` (classification system meant to categorize products)
# - `root_domain` (doesn't include the `www.` subdomain or `https://`/ `http://` protocols)
# - `page_url` (the full path, contains `root_domain`)
# - `product_title`
# - `product_summary`
# - `product_name` (less detailed than `product_title`)
#
# In addition to these key columns, there are **25** other columns that are less relevant (for example `description` represents the columns `product_name` and `product_summary` combined and slighlty modified, making it redundant).

# %% [markdown]
# ---
# The `describe()` method is able to identify in columns containing integers additional information that informs me that there are negative values for `manufacturing_year` (int32), indicating corrupted data.

# %%
df.describe()
# Out:
#        manufacturing_year
# count             21946.0
# mean                 -1.0
# std                   0.0
# min                  -1.0
# 25%                  -1.0
# 50%                  -1.0
# 75%                  -1.0
# max                  -1.0

# %% [markdown]
# The `info()` method provides some great insight as well.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21946 entries, 0 to 21945
# Data columns (total 31 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   unspsc                                21946 non-null  object
#  1   root_domain                           21946 non-null  object
#  2   page_url                              21946 non-null  object
#  3   product_title                         21946 non-null  object
#  4   product_summary                       20761 non-null  object
#  5   product_name                          21910 non-null  object
#  6   product_identifier                    21946 non-null  object
#  7   brand                                 7062 non-null   object
#  8   intended_industries                   21946 non-null  object
#  9   applicability                         21946 non-null  object
#  10  eco_friendly                          969 non-null    object
#  11  ethical_and_sustainability_practices  21946 non-null  object
#  12  production_capacity                   21946 non-null  object
#  13  price                                 21946 non-null  object
#  14  materials                             21946 non-null  object
#  15  ingredients                           21946 non-null  object
#  16  manufacturing_countries               21946 non-null  object
#  17  manufacturing_year                    21946 non-null  int32
#  18  manufacturing_type                    21946 non-null  object
#  19  customization                         21946 non-null  object
#  20  packaging_type                        21946 non-null  object
#  21  form                                  21946 non-null  object
#  22  size                                  21946 non-null  object
#  23  color                                 21946 non-null  object
#  24  purity                                21946 non-null  object
#  25  energy_efficiency                     177 non-null    object
#  26  pressure_rating                       21946 non-null  object
#  27  power_rating                          21946 non-null  object
#  28  quality_standards_and_certifications  21946 non-null  object
#  29  miscellaneous_features                21946 non-null  object
#  30  description                           20775 non-null  object
# dtypes: int32(1), object(30)
# memory usage: 5.1+ MB

# %% [markdown]
# It can be observed that out of the **31** columns, `product_summary`, `product_name`, `description` are missing very few entries containing no information, whereas the columns `brand`, `eco_friendly`, `energy_efficiency` are almost irrelevant for our purpose of eliminating product duplicates. It must be noted that `brand` is indeed an important parameter, however `root_domain` and `page-url` should at least identify the comerciants.
#
# Intuitively, the rest of these columns, regardless of whether they appear to have no missing data, are formatted in a way where a space detected is still considered valid in terms of not-null data.

# %% [markdown]
# ### Normalization
# <i><b>(lowercasing + removing any characters that are not alphanumeric)</b></i>
#
# #### Idea⭐
# The conclusion is that there's no reason to use the method `df.dropna()` for a certain subset of columns since they are not relevant, however I should format the string objects so that all letters will be lowercase, eliminate all spaces where they are not followed by other characters or that are positioned at the beggining/ end of a sentence, and conjunctions.
#
# ---

# %% [markdown]
# Here is some code to further investigate how the not-null values should be treated.
# > As mentioned above, transforming into lowercase and eliminating spaces is a priority
#
# A copy of the original `df` is created and will be used for the rest of the project (`cleaned_df` has its own memory allocation thanks to `copy()` method, being impossible to interfere with values stored in `df`). I begin to select the columns having the `object` data type (all apart from `manufacturing_year`) and iterate over each column. Then just like in a **SQL** query, we count the number of null values for that specific column, just to see their relevance.
#
# Afterwards, the prior cleaning consists of:
# > `fillna('')`: replaces all missing values in the column with an empty string </br>
# > `fillna('')` is called before applying lowercase `str.lower()` only because it would fail since there null values don't have a corresponding lowercase version </br>
# > `r'^\s*$'` is used to match strings that are either completely empty or contain only whitespace characters and these matches are replaced with null values (from **numpy** module) to ensure emptiness for certain entries

# %%
import numpy as np

cleaned_df = df.copy()
string_columns = cleaned_df.select_dtypes(include=['object']).columns

for col in string_columns:
    if cleaned_df[col].isnull().sum() > 0:
        print(f'Column {col} has {cleaned_df[col].isnull().sum()} missing values')
    
    cleaned_df[col] = cleaned_df[col].fillna('').str.lower()
    cleaned_df[col] = cleaned_df[col].replace(r'^\s*$', np.nan, regex=True)
cleaned_df
# Out:
# Column product_summary has 1185 missing values
# Column product_name has 36 missing values
# Column brand has 14884 missing values
# Column eco_friendly has 20977 missing values
# C:\Users\alice\AppData\Local\Temp\ipykernel_20152\1530634457.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cleaned_df[col] = cleaned_df[col].replace(r'^\s*$', np.nan, regex=True)
# Column energy_efficiency has 21769 missing values
# Column description has 1171 missing values
#                                                   unspsc  \
# 0      sewing and stitchery and weaving equipment and...
# 1                 electric alternating current ac motors
# 2                     vehicle trim and exterior covering
# 3                                        pipe connectors
# 4                                                  doors
# ...                                                  ...
# 21941                                              other
# 21942                     processed and synthetic rubber
# 21943                            fresh cut rose bouquets
# 21944  vision correction or cosmetic eyewear and rela...
# 21945       chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-cst-hgd-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                        product_title  \
# 0                        glimakra warping board (8m)
# 1                            nmrv worm gearbox motor
# 2                           nissan r33 gtr car cover
# 3                                  flexible fittings
# 4                   cst-hgd-33103 hinged closet door
# ...                                              ...
# 21941                              15/16 accessories
# 21942                general mechanical rubber goods
# 21943                          luxurious rose garden
# 21944  dailies aquacomfort plus multifocal (30 pack)
# 21945   signature dark collection 85% dark chocolate
#
#                                          product_summary  \
# 0      the glimakra warping board is designed for use...
# 1      the nmrv worm gearbox motor is a high-efficien...
# 2      a custom car cover designed for the nissan r33...
# 3      flexible fittings for plumbing applications, a...
# 4      the cst-hgd-33103 hinged closet door is a meti...
# ...                                                  ...
# 21941  accessories designed for sweet 15/16, availabl...
# 21942  a category of rubber goods designed for genera...
# 21943  the luxurious rose garden is a stunning floral...
# 21944  a pack of 30 dailies aquacomfort plus multifoc...
# 21945  a signature dark collection product from malag...
#
#                     product_name  product_identifier  \
# 0                  warping board                 NaN
# 1             worm gearbox motor                 NaN
# 2                      car cover                 NaN
# 3              flexible fittings                 NaN
# 4             hinged closet door                 NaN
# ...                          ...                 ...
# 21941                accessories                 NaN
# 21942               rubber goods                 NaN
# 21943         floral arrangement                 NaN
# 21944  multifocal contact lenses                 NaN
# 21945             dark chocolate                 NaN
#
#                             brand  intended_industries  applicability  ...  \
# 0                             NaN                  NaN            NaN  ...
# 1                             NaN                  NaN            NaN  ...
# 2                             NaN                  NaN            NaN  ...
# 3                             NaN                  NaN            NaN  ...
# 4                             cst                  NaN            NaN  ...
# ...                           ...                  ...            ...  ...
# 21941                         NaN                  NaN            NaN  ...
# 21942                         NaN                  NaN            NaN  ...
# 21943  lily of the valley florist                  NaN            NaN  ...
# 21944                     dailies                  NaN            NaN  ...
# 21945           malagos chocolate                  NaN            NaN  ...
#
#        form  size  color  purity  energy_efficiency  pressure_rating  \
# 0       NaN   NaN    NaN     NaN                NaN              NaN
# 1       NaN   NaN    NaN     NaN                NaN              NaN
# 2       NaN   NaN    NaN     NaN                NaN              NaN
# 3       NaN   NaN    NaN     NaN                NaN              NaN
# 4       NaN   NaN    NaN     NaN                NaN              NaN
# ...     ...   ...    ...     ...                ...              ...
# 21941   NaN   NaN    NaN     NaN                NaN              NaN
# 21942   NaN   NaN    NaN     NaN                NaN              NaN
# 21943   NaN   NaN    NaN     NaN                NaN              NaN
# 21944   NaN   NaN    NaN     NaN                NaN              NaN
# 21945   NaN   NaN    NaN     NaN                NaN              NaN
#
#        power_rating  quality_standards_and_certifications  \
# 0               NaN                                   NaN
# 1               NaN                                   NaN
# 2               NaN                                   NaN
# 3               NaN                                   NaN
# 4               NaN                                   NaN
# ...             ...                                   ...
# 21941           NaN                                   NaN
# 21942           NaN                                   NaN
# 21943           NaN                                   NaN
# 21944           NaN                                   NaN
# 21945           NaN                                   NaN
#
#        miscellaneous_features  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 21941                     NaN
# 21942                     NaN
# 21943                     NaN
# 21944                     NaN
# 21945                     NaN
#
#                                              description
# 0      the "warping board" is designed for use with f...
# 1      the "worm gearbox motor" is a high-efficiency ...
# 2      the "car cover" is a custom-designed cover tai...
# 3      "flexible fittings" are designed for plumbing ...
# 4      the "hinged closet door" is a storage solution...
# ...                                                  ...
# 21941  "accessories" are designed for use with sweet ...
# 21942  "rubber goods" are designed for general mechan...
# 21943  "the 'floral arrangement' offered by lily of t...
# 21944  "multifocal contact lenses" are designed for d...
# 21945  "dark chocolate" from malagos chocolate is a r...
#
# [21946 rows x 31 columns]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21946 entries, 0 to 21945
# Data columns (total 31 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   unspsc                                21946 non-null  object
#  1   root_domain                           21946 non-null  object
#  2   page_url                              21946 non-null  object
#  3   product_title                         21946 non-null  object
#  4   product_summary                       20761 non-null  object
#  5   product_name                          21910 non-null  object
#  6   product_identifier                    0 non-null      float64
#  7   brand                                 7062 non-null   object
#  8   intended_industries                   0 non-null      float64
#  9   applicability                         0 non-null      float64
#  10  eco_friendly                          0 non-null      float64
#  11  ethical_and_sustainability_practices  0 non-null      float64
#  12  production_capacity                   0 non-null      float64
#  13  price                                 0 non-null      float64
#  14  materials                             0 non-null      float64
#  15  ingredients                           0 non-null      float64
#  16  manufacturing_countries               0 non-null      float64
#  17  manufacturing_year                    21946 non-null  int32
#  18  manufacturing_type                    0 non-null      float64
#  19  customization                         0 non-null      float64
#  20  packaging_type                        0 non-null      float64
#  21  form                                  0 non-null      float64
#  22  size                                  0 non-null      float64
#  23  color                                 0 non-null      float64
#  24  purity                                0 non-null      float64
#  25  energy_efficiency                     0 non-null      float64
#  26  pressure_rating                       0 non-null      float64
#  27  power_rating                          0 non-null      float64
#  28  quality_standards_and_certifications  0 non-null      float64
#  29  miscellaneous_features                0 non-null      float64
#  30  description                           20775 non-null  object
# dtypes: float64(22), int32(1), object(8)
# memory usage: 5.1+ MB

# %% [markdown]
# > Interesting difference between data types in `df` and `cleaned_df` </br>
# I assume the regex replacement influenced some **object** data type defined columns to become **float64**.
#
# ---

# %% [markdown]
# Knowing `.duplicated()` can be performed on a subset of columns that I find relevant, it is rather simple to say that I can identify exactly **16** duplicates.

# %%
duplicates = cleaned_df[cleaned_df.duplicated(subset=['unspsc', 'product_title', 'page_url', 'root_domain'], keep=False)].sort_values(by='product_title')
print(f'Total duplicate rows based on the 4 main identifiers: {duplicates.shape[0]}')
duplicates
# Out:
# Total duplicate rows based on the 4 main identifiers: 16
#                                         unspsc               root_domain  \
# 6266       domestic kitchen tools and utensils              millargb.com
# 9604       domestic kitchen tools and utensils              millargb.com
# 701                    personal paper products            babysoft.co.za
# 6816                   personal paper products            babysoft.co.za
# 3103   automation control connectivity devices              trombetta.co
# 5069   automation control connectivity devices              trombetta.co
# 6285                infant foods and beverages       kendalnutricare.com
# 6384                infant foods and beverages       kendalnutricare.com
# 384      agricultural machinery for harvesting      fxforagerparts.co.uk
# 4028     agricultural machinery for harvesting      fxforagerparts.co.uk
# 8901                          power generators  allsmallenginerepair.com
# 9193                          power generators  allsmallenginerepair.com
# 8934                               compressors        ranecommercial.com
# 9264                               compressors        ranecommercial.com
# 9268                                  bearings              actparts.com
# 11658                                 bearings              actparts.com
#
#                                                 page_url  \
# 6266                            https://millargb.com/en/
# 9604                            https://millargb.com/en/
# 701                          https://www.babysoft.co.za/
# 6816                         https://www.babysoft.co.za/
# 3103                               https://trombetta.co/
# 5069                               https://trombetta.co/
# 6285                        https://kendalnutricare.com/
# 6384                        https://kendalnutricare.com/
# 384                     http://www.fxforagerparts.co.uk/
# 4028                    http://www.fxforagerparts.co.uk/
# 8901               https://www.allsmallenginerepair.com/
# 9193               https://www.allsmallenginerepair.com/
# 8934           https://www.ranecommercial.com/legacy.php
# 9264           https://www.ranecommercial.com/legacy.php
# 9268   https://www.actparts.com/fr/products/bearings/...
# 11658  https://www.actparts.com/fr/products/bearings/...
#
#                                            product_title  \
# 6266                                         accessories
# 9604                                         accessories
# 701                 baby soft® fresh moist toilet tissue
# 6816                baby soft® fresh moist toilet tissue
# 3103                                     canopen devices
# 5069                                     canopen devices
# 6285                                  kendamil baby milk
# 6384                                  kendamil baby milk
# 384    new holland forage harvester parts for nh fx s...
# 4028   new holland forage harvester parts for nh fx s...
# 8901                           portable generator repair
# 9193                           portable generator repair
# 8934                                             rane c4
# 9264                                             rane c4
# 9268                                   spherical bearing
# 11658                                  spherical bearing
#
#                                          product_summary  \
# 6266   a selection of kitchen accessories to compleme...
# 9604   a category of kitchen accessories to complemen...
# 701    a fresh moist toilet tissue product from baby ...
# 6816   a fresh moist toilet tissue product that offer...
# 3103   dc power products designed for a variety of ap...
# 5069   trombetta offers a full range of products that...
# 6285   kendamil baby milk is a world-class nutrition ...
# 6384   kendamil baby milk is a british-made product, ...
# 384    new holland forage harvester parts for nh fx s...
# 4028   new holland forage harvester parts for nh fx s...
# 8901   diagnostic and repair services for portable ge...
# 9193   service for repairing portable generators, mai...
# 8934   a discontinued compressor model from rane, ori...
# 9264   a discontinued compressor model from rane, ori...
# 9268   a spherical bearing suitable for various appli...
# 11658  a spherical bearing suitable for various appli...
#
#                     product_name  product_identifier             brand  \
# 6266         kitchen accessories                 NaN               NaN
# 9604         kitchen accessories                 NaN               NaN
# 701    fresh moist toilet tissue                 NaN        baby soft®
# 6816   fresh moist toilet tissue                 NaN         baby soft
# 3103             canopen devices                 NaN               NaN
# 5069             canopen devices                 NaN         trombetta
# 6285                   baby milk                 NaN          kendamil
# 6384                   baby milk                 NaN  kendal nutricare
# 384       forage harvester parts                 NaN       new holland
# 4028      forage harvester parts                 NaN       new holland
# 8901   portable generator repair                 NaN               NaN
# 9193   portable generator repair                 NaN               NaN
# 8934                  compressor                 NaN              rane
# 9264                  compressor                 NaN              rane
# 9268           spherical bearing                 NaN               NaN
# 11658          spherical bearing                 NaN               NaN
#
#        intended_industries  applicability  ...  form  size  color  purity  \
# 6266                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 9604                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 701                    NaN            NaN  ...   NaN   NaN    NaN     NaN
# 6816                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 3103                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 5069                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 6285                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 6384                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 384                    NaN            NaN  ...   NaN   NaN    NaN     NaN
# 4028                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 8901                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 9193                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 8934                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 9264                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 9268                   NaN            NaN  ...   NaN   NaN    NaN     NaN
# 11658                  NaN            NaN  ...   NaN   NaN    NaN     NaN
#
#        energy_efficiency  pressure_rating  power_rating  \
# 6266                 NaN              NaN           NaN
# 9604                 NaN              NaN           NaN
# 701                  NaN              NaN           NaN
# 6816                 NaN              NaN           NaN
# 3103                 NaN              NaN           NaN
# 5069                 NaN              NaN           NaN
# 6285                 NaN              NaN           NaN
# 6384                 NaN              NaN           NaN
# 384                  NaN              NaN           NaN
# 4028                 NaN              NaN           NaN
# 8901                 NaN              NaN           NaN
# 9193                 NaN              NaN           NaN
# 8934                 NaN              NaN           NaN
# 9264                 NaN              NaN           NaN
# 9268                 NaN              NaN           NaN
# 11658                NaN              NaN           NaN
#
#        quality_standards_and_certifications  miscellaneous_features  \
# 6266                                    NaN                     NaN
# 9604                                    NaN                     NaN
# 701                                     NaN                     NaN
# 6816                                    NaN                     NaN
# 3103                                    NaN                     NaN
# 5069                                    NaN                     NaN
# 6285                                    NaN                     NaN
# 6384                                    NaN                     NaN
# 384                                     NaN                     NaN
# 4028                                    NaN                     NaN
# 8901                                    NaN                     NaN
# 9193                                    NaN                     NaN
# 8934                                    NaN                     NaN
# 9264                                    NaN                     NaN
# 9268                                    NaN                     NaN
# 11658                                   NaN                     NaN
#
#                                              description
# 6266   "kitchen accessories" are a selection of kitch...
# 9604   "kitchen accessories" are designed to compleme...
# 701    "baby soft fresh moist toilet tissue" is a toi...
# 6816   "baby soft fresh moist toilet tissue" is a fre...
# 3103   "canopen devices" are dc power products design...
# 5069   "canopen devices" manufactured by trombetta ar...
# 6285   "baby milk" is a baby formula produced in kend...
# 6384   "baby milk" is a british-made product crafted ...
# 384    "forage harvester parts" are essential mainten...
# 4028   "forage harvester parts" are essential mainten...
# 8901   "portable generator repair" provides diagnosti...
# 9193   "portable generator repair" is a service desig...
# 8934   "the 'compressor' is a discontinued compressor...
# 9264   "the 'compressor' is a discontinued compressor...
# 9268   "the 'spherical bearing' is identified by prod...
# 11658  the "spherical bearing" is identified by produ...
#
# [16 rows x 31 columns]

# %% [markdown]
# In the next section I tried dropping the other match since out of the **16** pairs, the first entity could've remained in the data frame.

# %%
# cleaned_df.drop_duplicates(subset=['unspsc', 'product_title', 'page_url', 'root_domain'], keep='first', inplace=True)
# print(f'Number of cleaned rows: {df.shape[0]-cleaned_df.shape[0]}')
# cleaned_df

# %% [markdown]
# ---
#
# The purpose of cleaning the data in `cleaned_df` is to remove all anomalies, specifically characters that are not letters or digits.  To achieve this, a regex pattern is applied to replace any characters that do not match with an empty string, ensuring that only valid alphanumeric characters (**[a-zA-Z0-9 ]**) remain in the dataset.

# %%
cleaned_df['product_title'].str.replace("[a-zA-Z0-9 ]", "", regex=True).unique()
# Out:
# array(['()', '', '--', ..., '––/', '()--/', '|石斑鱼'],
#       shape=(1686,), dtype=object)

# %%
subset_columns = ['product_name', 'product_title', 'product_summary']

aux_df = cleaned_df[subset_columns].copy() # since we know it will output the unwanted characters, without the needed ones, we decide not to modify cleaned_df yet
for col in subset_columns:
    aux_df[col] = aux_df[col].str.replace("[a-zA-Z0-9 ]", "", regex=True)
aux_df
# Out:
#       product_name product_title  \
# 0                             ()
# 1
# 2
# 3
# 4                             --
# ...            ...           ...
# 21941                          /
# 21942
# 21943
# 21944                         ()
# 21945                          %
#
#                                          product_summary
# 0                                                  ,.,원.
# 1      -..,.,.,.,.,.,.,.,.,.,.,,.,.,,.,,,,,,,,,,,,,,,...
# 2                                                   .,,.
# 3                                                     ,.
# 4                              --,.,-.--,,.,.,.,.,,,.',.
# ...                                                  ...
# 21941                                             /,/"..
# 21942                                                 ,.
# 21943                          ,:.£.,£...,.-.,.,,,.,-.,.
# 21944                                            ,.,.$..
# 21945                                                ,%.
#
# [21946 rows x 3 columns]

# %%
for col in subset_columns:
    print(f"Unique values in '{col}': {aux_df[col].unique()}")
# Out:
# Unique values in 'product_name': ['' '-' '---' '--' '/' '-#-' ',-' '/"' '-/' '&' ',' "'" '.' ',,,,' nan
#  '-..-' '°' '--/' '–' ',&' '+' '®®' ',,,' '.-' '..' "'-" '™' '&-' "-''"
#  '()' '&-&' '/-' "-'-" '----' 'สวสัสวัสวัส' ',()--' ',,' 'é' '"' '°---'
#  '|-' '-/"-' ':' '-----' '()/()-' '()–' '---.-' '--.' '’' '..-' '®-' '%'
#  '/()' ',"' '-,' 'สวสัสวัส' '-()' '®™' '-(),,&' '----//' ',---' '"-' '//'
#  '(---)' '-,,,-' '&&' '-..--' '-(+),-' '++' '--...' '®' "'--" '-&' '.:/'
#  '--;' '(-©)' '°-' '------' '/.' '_/-' '...' ',°-' 'µ()' '®’' '--™'
#  "--'---" '-/"(±")' '_+_' '&&//.&' '-,&' '--*-' '[()--]' '#-' '-°---' '."'
#  '-*' '--++' '.%' "'&" '-+' ',...:' '&/' '+.' '.(.)' '&.' '(-)' '()-'
#  '×–-' ',,,,,,' '(/)' '---(-----)' '″()' '+×' '-,-' '////' '///' '硫压片' 'ó'
#  '-,,(:)()' 'ô.' '’-' '--()' '-.' 'â' ',ó,,' ':,' '-#' '/--' 'â-é' 'ö'
#  '&()' "''" ',-()' '£' '!!' '--+' '.....' 'ابراتلداتنامداتنامداتنامداتن'
#  '--[]' '-./' '-,,' ',--' '&’' '--!' '.---.' '(,)' "+''/////" '-ó' './'
#  ',,&' '|' '’&' '-α--' '-(‐-‐-)' 'полотнакостенные' '&-&-'
#  '---(,,,--,---)--' "-'" ',-,' '™-()' '--,' '(-----)]-' '&,' '硫名硣名' '.+'
#  '-/-/' '-,()' '/%//.”' 'β-' ':&' '-(---(,-)[,-]--)--(-)' '_']
# Unique values in 'product_title': ['()' '' '--' ... '––/' '()--/' '|石斑鱼']
# Unique values in 'product_summary': [',.,원.'
#  '-..,.,.,.,.,.,.,.,.,.,.,,.,.,,.,,,,,,,,,,,,,,,.:.,,,,,,,,,,.---.,-.-#.,,..-.'
#  '.,,.' ... '//..,.' '/,/"..' ',:.£.,£...,.-.,.,,,.,-.,.']

# %% [markdown]
# When ^ is used inside square brackets ([^a-zA-Z0-9 ]), it negates the character class, meaning the logic illustrated above can easily be implemented for cleaned_df.

# %%
for col in subset_columns:
    cleaned_df[col] = cleaned_df[col].str.replace("[^a-zA-Z0-9 ]", "", regex=True)
cleaned_df
# Out:
#                                                   unspsc  \
# 0      sewing and stitchery and weaving equipment and...
# 1                 electric alternating current ac motors
# 2                     vehicle trim and exterior covering
# 3                                        pipe connectors
# 4                                                  doors
# ...                                                  ...
# 21941                                              other
# 21942                     processed and synthetic rubber
# 21943                            fresh cut rose bouquets
# 21944  vision correction or cosmetic eyewear and rela...
# 21945       chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-cst-hgd-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                      product_title  \
# 0                        glimakra warping board 8m
# 1                          nmrv worm gearbox motor
# 2                         nissan r33 gtr car cover
# 3                                flexible fittings
# 4                   csthgd33103 hinged closet door
# ...                                            ...
# 21941                             1516 accessories
# 21942              general mechanical rubber goods
# 21943                        luxurious rose garden
# 21944  dailies aquacomfort plus multifocal 30 pack
# 21945  signature dark collection 85 dark chocolate
#
#                                          product_summary  \
# 0      the glimakra warping board is designed for use...
# 1      the nmrv worm gearbox motor is a highefficienc...
# 2      a custom car cover designed for the nissan r33...
# 3      flexible fittings for plumbing applications al...
# 4      the csthgd33103 hinged closet door is a meticu...
# ...                                                  ...
# 21941  accessories designed for sweet 1516 available ...
# 21942  a category of rubber goods designed for genera...
# 21943  the luxurious rose garden is a stunning floral...
# 21944  a pack of 30 dailies aquacomfort plus multifoc...
# 21945  a signature dark collection product from malag...
#
#                     product_name  product_identifier  \
# 0                  warping board                 NaN
# 1             worm gearbox motor                 NaN
# 2                      car cover                 NaN
# 3              flexible fittings                 NaN
# 4             hinged closet door                 NaN
# ...                          ...                 ...
# 21941                accessories                 NaN
# 21942               rubber goods                 NaN
# 21943         floral arrangement                 NaN
# 21944  multifocal contact lenses                 NaN
# 21945             dark chocolate                 NaN
#
#                             brand  intended_industries  applicability  ...  \
# 0                             NaN                  NaN            NaN  ...
# 1                             NaN                  NaN            NaN  ...
# 2                             NaN                  NaN            NaN  ...
# 3                             NaN                  NaN            NaN  ...
# 4                             cst                  NaN            NaN  ...
# ...                           ...                  ...            ...  ...
# 21941                         NaN                  NaN            NaN  ...
# 21942                         NaN                  NaN            NaN  ...
# 21943  lily of the valley florist                  NaN            NaN  ...
# 21944                     dailies                  NaN            NaN  ...
# 21945           malagos chocolate                  NaN            NaN  ...
#
#        form  size  color  purity  energy_efficiency  pressure_rating  \
# 0       NaN   NaN    NaN     NaN                NaN              NaN
# 1       NaN   NaN    NaN     NaN                NaN              NaN
# 2       NaN   NaN    NaN     NaN                NaN              NaN
# 3       NaN   NaN    NaN     NaN                NaN              NaN
# 4       NaN   NaN    NaN     NaN                NaN              NaN
# ...     ...   ...    ...     ...                ...              ...
# 21941   NaN   NaN    NaN     NaN                NaN              NaN
# 21942   NaN   NaN    NaN     NaN                NaN              NaN
# 21943   NaN   NaN    NaN     NaN                NaN              NaN
# 21944   NaN   NaN    NaN     NaN                NaN              NaN
# 21945   NaN   NaN    NaN     NaN                NaN              NaN
#
#        power_rating  quality_standards_and_certifications  \
# 0               NaN                                   NaN
# 1               NaN                                   NaN
# 2               NaN                                   NaN
# 3               NaN                                   NaN
# 4               NaN                                   NaN
# ...             ...                                   ...
# 21941           NaN                                   NaN
# 21942           NaN                                   NaN
# 21943           NaN                                   NaN
# 21944           NaN                                   NaN
# 21945           NaN                                   NaN
#
#        miscellaneous_features  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 21941                     NaN
# 21942                     NaN
# 21943                     NaN
# 21944                     NaN
# 21945                     NaN
#
#                                              description
# 0      the "warping board" is designed for use with f...
# 1      the "worm gearbox motor" is a high-efficiency ...
# 2      the "car cover" is a custom-designed cover tai...
# 3      "flexible fittings" are designed for plumbing ...
# 4      the "hinged closet door" is a storage solution...
# ...                                                  ...
# 21941  "accessories" are designed for use with sweet ...
# 21942  "rubber goods" are designed for general mechan...
# 21943  "the 'floral arrangement' offered by lily of t...
# 21944  "multifocal contact lenses" are designed for d...
# 21945  "dark chocolate" from malagos chocolate is a r...
#
# [21946 rows x 31 columns]

# %% [markdown]
# ---
#
# ### Tokenization
# <i><b>(and normalization: removing stop words)</b></i>
#
# The last part of the `clean_string_data.ipynb` notebook focuses on tokenizing the text in the `product_title` and `product_name` columns. It also includes a step to remove stop words, which I have manually curated into a small set.
#
# Later in the process, I found out about the possibility of using `TfidfVectorizer` to convert sentences into numerical vectors based on word frequencies, similar to tokenization. Additionally, this method allows to remove stop words by setting the **stop_words** flag to 'english', which effectively eliminates a large set of common English words that do not significantly contribute to the meaning of the text and might even influence negatively how the similarity is handled between sentences.
#
# Therefore, I decided not to tackle the problem in this primitive manner in the [`deduplication_script.py` (link for path here)](./deduplication_script.py) file containing the final version of the project.

# %%
'''def tokenize(text):
    if isinstance(text, str):
        return text.split()
    return []'''
cleaned_df['product_name_tokens'] = cleaned_df['product_name'].apply(
    lambda x: x.split() if isinstance(x, str) else []
)
cleaned_df['product_title_tokens'] = cleaned_df['product_title'].apply(
    lambda x: x.split() if isinstance(x, str) else []
)
cleaned_df
# Out:
#                                                   unspsc  \
# 0      sewing and stitchery and weaving equipment and...
# 1                 electric alternating current ac motors
# 2                     vehicle trim and exterior covering
# 3                                        pipe connectors
# 4                                                  doors
# ...                                                  ...
# 21941                                              other
# 21942                     processed and synthetic rubber
# 21943                            fresh cut rose bouquets
# 21944  vision correction or cosmetic eyewear and rela...
# 21945       chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-cst-hgd-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                      product_title  \
# 0                        glimakra warping board 8m
# 1                          nmrv worm gearbox motor
# 2                         nissan r33 gtr car cover
# 3                                flexible fittings
# 4                   csthgd33103 hinged closet door
# ...                                            ...
# 21941                             1516 accessories
# 21942              general mechanical rubber goods
# 21943                        luxurious rose garden
# 21944  dailies aquacomfort plus multifocal 30 pack
# 21945  signature dark collection 85 dark chocolate
#
#                                          product_summary  \
# 0      the glimakra warping board is designed for use...
# 1      the nmrv worm gearbox motor is a highefficienc...
# 2      a custom car cover designed for the nissan r33...
# 3      flexible fittings for plumbing applications al...
# 4      the csthgd33103 hinged closet door is a meticu...
# ...                                                  ...
# 21941  accessories designed for sweet 1516 available ...
# 21942  a category of rubber goods designed for genera...
# 21943  the luxurious rose garden is a stunning floral...
# 21944  a pack of 30 dailies aquacomfort plus multifoc...
# 21945  a signature dark collection product from malag...
#
#                     product_name  product_identifier  \
# 0                  warping board                 NaN
# 1             worm gearbox motor                 NaN
# 2                      car cover                 NaN
# 3              flexible fittings                 NaN
# 4             hinged closet door                 NaN
# ...                          ...                 ...
# 21941                accessories                 NaN
# 21942               rubber goods                 NaN
# 21943         floral arrangement                 NaN
# 21944  multifocal contact lenses                 NaN
# 21945             dark chocolate                 NaN
#
#                             brand  intended_industries  applicability  ...  \
# 0                             NaN                  NaN            NaN  ...
# 1                             NaN                  NaN            NaN  ...
# 2                             NaN                  NaN            NaN  ...
# 3                             NaN                  NaN            NaN  ...
# 4                             cst                  NaN            NaN  ...
# ...                           ...                  ...            ...  ...
# 21941                         NaN                  NaN            NaN  ...
# 21942                         NaN                  NaN            NaN  ...
# 21943  lily of the valley florist                  NaN            NaN  ...
# 21944                     dailies                  NaN            NaN  ...
# 21945           malagos chocolate                  NaN            NaN  ...
#
#        color  purity  energy_efficiency  pressure_rating  power_rating  \
# 0        NaN     NaN                NaN              NaN           NaN
# 1        NaN     NaN                NaN              NaN           NaN
# 2        NaN     NaN                NaN              NaN           NaN
# 3        NaN     NaN                NaN              NaN           NaN
# 4        NaN     NaN                NaN              NaN           NaN
# ...      ...     ...                ...              ...           ...
# 21941    NaN     NaN                NaN              NaN           NaN
# 21942    NaN     NaN                NaN              NaN           NaN
# 21943    NaN     NaN                NaN              NaN           NaN
# 21944    NaN     NaN                NaN              NaN           NaN
# 21945    NaN     NaN                NaN              NaN           NaN
#
#        quality_standards_and_certifications  miscellaneous_features  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# ...                                     ...                     ...
# 21941                                   NaN                     NaN
# 21942                                   NaN                     NaN
# 21943                                   NaN                     NaN
# 21944                                   NaN                     NaN
# 21945                                   NaN                     NaN
#
#                                              description  \
# 0      the "warping board" is designed for use with f...
# 1      the "worm gearbox motor" is a high-efficiency ...
# 2      the "car cover" is a custom-designed cover tai...
# 3      "flexible fittings" are designed for plumbing ...
# 4      the "hinged closet door" is a storage solution...
# ...                                                  ...
# 21941  "accessories" are designed for use with sweet ...
# 21942  "rubber goods" are designed for general mechan...
# 21943  "the 'floral arrangement' offered by lily of t...
# 21944  "multifocal contact lenses" are designed for d...
# 21945  "dark chocolate" from malagos chocolate is a r...
#
#                  product_name_tokens  \
# 0                   [warping, board]
# 1             [worm, gearbox, motor]
# 2                       [car, cover]
# 3               [flexible, fittings]
# 4             [hinged, closet, door]
# ...                              ...
# 21941                  [accessories]
# 21942                [rubber, goods]
# 21943          [floral, arrangement]
# 21944  [multifocal, contact, lenses]
# 21945              [dark, chocolate]
#
#                                     product_title_tokens
# 0                         [glimakra, warping, board, 8m]
# 1                           [nmrv, worm, gearbox, motor]
# 2                         [nissan, r33, gtr, car, cover]
# 3                                   [flexible, fittings]
# 4                    [csthgd33103, hinged, closet, door]
# ...                                                  ...
# 21941                                [1516, accessories]
# 21942               [general, mechanical, rubber, goods]
# 21943                          [luxurious, rose, garden]
# 21944  [dailies, aquacomfort, plus, multifocal, 30, p...
# 21945  [signature, dark, collection, 85, dark, chocol...
#
# [21946 rows x 33 columns]

# %%
stop_words = {'product', 'products', 'make', 'makes', 'use', 'allowing', 'allows', 'available', 'a', 'an', 'and', 'is', 'the', 'of', 'for', 'plus', 'with', 'to', 'in', 'on', 'at', 'by', 'as', 'from', 'that', 'this', 'these', 'those', 'or', 'but', 'not', 'over', 'under', 'above', 'below', 'between', 'among', 'through', 'into', 'onto', 'after', 'before', 'since', 'during', 'while', 'if', 'then', 'else', 'when', 'where', 'why', 'how', 'all', 'any', 'each', 'every', 'other', 'another', 'such', 'own', 'same', 'different', 'more', 'less', 'few', 'many', 'most', 'some', 'several', 'fewer'}

def remove_stop_words(text):
    if not isinstance(text, str):
        return text 
    tokens = text.split()
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    return ' '.join(filtered_tokens)

cleaned_df['product_summary_stop_words_removed'] = cleaned_df['product_summary'].apply(remove_stop_words)
cleaned_df
# Out:
#                                                   unspsc  \
# 0      sewing and stitchery and weaving equipment and...
# 1                 electric alternating current ac motors
# 2                     vehicle trim and exterior covering
# 3                                        pipe connectors
# 4                                                  doors
# ...                                                  ...
# 21941                                              other
# 21942                     processed and synthetic rubber
# 21943                            fresh cut rose bouquets
# 21944  vision correction or cosmetic eyewear and rela...
# 21945       chocolate and sugars and sweetening products
#
#                          root_domain  \
# 0                  studio-atcoat.com
# 1                     worm-gears.net
# 2               customcarcoverco.com
# 3                    plumbmaster.com
# 4                           sogno.in
# ...                              ...
# 21941                   dsbridal.com
# 21942               50735-in.all.biz
# 21943             lilyofthevalley.uk
# 21944  getcontactlensesonline.com.au
# 21945           malagoschocolate.com
#
#                                                 page_url  \
# 0          https://studio-atcoat.com/1372696759/?idx=510
# 1              https://worm-gears.net/tag/worm-gear-box/
# 2      https://customcarcoverco.com/collections/vendo...
# 3      https://www.plumbmaster.com/search?q=wolverine...
# 4      http://www.sogno.in/product-detail-cst-hgd-331...
# ...                                                  ...
# 21941  https://www.dsbridal.com/index.php/sale/veils....
# 21942               https://50735-in.all.biz/group-goods
# 21943  https://www.lilyofthevalley.uk/product/luxurio...
# 21944  https://getcontactlensesonline.com.au/brand/al...
# 21945  https://malagoschocolate.com/collections/ready...
#
#                                      product_title  \
# 0                        glimakra warping board 8m
# 1                          nmrv worm gearbox motor
# 2                         nissan r33 gtr car cover
# 3                                flexible fittings
# 4                   csthgd33103 hinged closet door
# ...                                            ...
# 21941                             1516 accessories
# 21942              general mechanical rubber goods
# 21943                        luxurious rose garden
# 21944  dailies aquacomfort plus multifocal 30 pack
# 21945  signature dark collection 85 dark chocolate
#
#                                          product_summary  \
# 0      the glimakra warping board is designed for use...
# 1      the nmrv worm gearbox motor is a highefficienc...
# 2      a custom car cover designed for the nissan r33...
# 3      flexible fittings for plumbing applications al...
# 4      the csthgd33103 hinged closet door is a meticu...
# ...                                                  ...
# 21941  accessories designed for sweet 1516 available ...
# 21942  a category of rubber goods designed for genera...
# 21943  the luxurious rose garden is a stunning floral...
# 21944  a pack of 30 dailies aquacomfort plus multifoc...
# 21945  a signature dark collection product from malag...
#
#                     product_name  product_identifier  \
# 0                  warping board                 NaN
# 1             worm gearbox motor                 NaN
# 2                      car cover                 NaN
# 3              flexible fittings                 NaN
# 4             hinged closet door                 NaN
# ...                          ...                 ...
# 21941                accessories                 NaN
# 21942               rubber goods                 NaN
# 21943         floral arrangement                 NaN
# 21944  multifocal contact lenses                 NaN
# 21945             dark chocolate                 NaN
#
#                             brand  intended_industries  applicability  ...  \
# 0                             NaN                  NaN            NaN  ...
# 1                             NaN                  NaN            NaN  ...
# 2                             NaN                  NaN            NaN  ...
# 3                             NaN                  NaN            NaN  ...
# 4                             cst                  NaN            NaN  ...
# ...                           ...                  ...            ...  ...
# 21941                         NaN                  NaN            NaN  ...
# 21942                         NaN                  NaN            NaN  ...
# 21943  lily of the valley florist                  NaN            NaN  ...
# 21944                     dailies                  NaN            NaN  ...
# 21945           malagos chocolate                  NaN            NaN  ...
#
#        purity  energy_efficiency  pressure_rating  power_rating  \
# 0         NaN                NaN              NaN           NaN
# 1         NaN                NaN              NaN           NaN
# 2         NaN                NaN              NaN           NaN
# 3         NaN                NaN              NaN           NaN
# 4         NaN                NaN              NaN           NaN
# ...       ...                ...              ...           ...
# 21941     NaN                NaN              NaN           NaN
# 21942     NaN                NaN              NaN           NaN
# 21943     NaN                NaN              NaN           NaN
# 21944     NaN                NaN              NaN           NaN
# 21945     NaN                NaN              NaN           NaN
#
#        quality_standards_and_certifications  miscellaneous_features  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# ...                                     ...                     ...
# 21941                                   NaN                     NaN
# 21942                                   NaN                     NaN
# 21943                                   NaN                     NaN
# 21944                                   NaN                     NaN
# 21945                                   NaN                     NaN
#
#                                              description  \
# 0      the "warping board" is designed for use with f...
# 1      the "worm gearbox motor" is a high-efficiency ...
# 2      the "car cover" is a custom-designed cover tai...
# 3      "flexible fittings" are designed for plumbing ...
# 4      the "hinged closet door" is a storage solution...
# ...                                                  ...
# 21941  "accessories" are designed for use with sweet ...
# 21942  "rubber goods" are designed for general mechan...
# 21943  "the 'floral arrangement' offered by lily of t...
# 21944  "multifocal contact lenses" are designed for d...
# 21945  "dark chocolate" from malagos chocolate is a r...
#
#                  product_name_tokens  \
# 0                   [warping, board]
# 1             [worm, gearbox, motor]
# 2                       [car, cover]
# 3               [flexible, fittings]
# 4             [hinged, closet, door]
# ...                              ...
# 21941                  [accessories]
# 21942                [rubber, goods]
# 21943          [floral, arrangement]
# 21944  [multifocal, contact, lenses]
# 21945              [dark, chocolate]
#
#                                     product_title_tokens  \
# 0                         [glimakra, warping, board, 8m]
# 1                           [nmrv, worm, gearbox, motor]
# 2                         [nissan, r33, gtr, car, cover]
# 3                                   [flexible, fittings]
# 4                    [csthgd33103, hinged, closet, door]
# ...                                                  ...
# 21941                                [1516, accessories]
# 21942               [general, mechanical, rubber, goods]
# 21943                          [luxurious, rose, garden]
# 21944  [dailies, aquacomfort, plus, multifocal, 30, p...
# 21945  [signature, dark, collection, 85, dark, chocol...
#
#                       product_summary_stop_words_removed
# 0      glimakra warping board designed floor looms pr...
# 1      nmrv worm gearbox motor highefficiency gear bo...
# 2      custom car cover designed nissan r33 gtr model...
# 3      flexible fittings plumbing applications moveme...
# 4      csthgd33103 hinged closet door meticulously de...
# ...                                                  ...
# 21941  accessories designed sweet 1516 various sizes ...
# 21942  category rubber goods designed general mechani...
# 21943  luxurious rose garden stunning floral arrangem...
# 21944  pack 30 dailies aquacomfort multifocal contact...
# 21945  signature dark collection malagos chocolate 85...
#
# [21946 rows x 34 columns]

# %%
# %store cleaned_df
# Out:
# Stored 'cleaned_df' (DataFrame)
